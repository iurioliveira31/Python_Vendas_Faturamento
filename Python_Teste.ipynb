# %% [markdown]
# <a href="https://colab.research.google.com/github/iurioliveira31/Python_Vendas_Faturamento/blob/main/Python_Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Solução do desafio*

# %%
# Lógica de programação

# Passo 0 - Entender o desafio e resolver

# Passo 1 - Percorrer todos os arquivos da pasta base de dados (Pasta Vendas)
import os
import pandas as pd

lista_arquivo = os.listdir("/content/drive/MyDrive/Python Tabela/Vendas")
display(lista_arquivo)
# Out:
# ['Devolucoes - Fortaleza.csv',
#  'Vendas - Goiás.csv',
#  'Devolucoes - São Paulo.csv',
#  'Vendas - Recife.csv',
#  'Vendas - São Paulo.csv',
#  'Devolucoes - Curitiba.csv',
#  'Devolucoes - Salvador.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Recife.csv',
#  'Vendas - Curitiba.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - Goiás.csv',
#  'Devolucoes - Belo Horizonte.csv']

# %%
tabela_total = pd.DataFrame()

# Passo 2 - Importar a base de dados de vendas
for arquivo in lista_arquivo:
  # se tem "Vendas" no nome do arquivo, então
  if "Vendas" in arquivo:
    # importar o aquivo
    tabela = pd.read_csv(f"/content/drive/MyDrive/Python Tabela/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)


# Passo 3 - Tratar/Compilar as bases de dados
display(tabela_total)
# Out:
# <ipython-input-18-b7d9ecaa357d>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# <ipython-input-18-b7d9ecaa357d>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# <ipython-input-18-b7d9ecaa357d>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# <ipython-input-18-b7d9ecaa357d>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# ...

# %%
# Passo 4 - Calcular o produto mais vendido (em quantidades)
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
# <ipython-input-27-ef7956b44f79>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_produtos = tabela_total.groupby('Produto').sum()
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805

# %%
# Passo 5 - Calcular o produto que mais faturou (em faturamento)
tabela_total['Faturamento']= tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']
tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
# <ipython-input-36-1f16d426f7ea>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_faturamento = tabela_total.groupby('Produto').sum()
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
# Passo 6 - Calcular a loja/cidade que mais vendeu (em faturamento) - criar gráfico/dashboard
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
# <ipython-input-38-ce828d81fd89>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_lojas = tabela_total.groupby('Loja').sum()
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
import plotly.express as px

grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
